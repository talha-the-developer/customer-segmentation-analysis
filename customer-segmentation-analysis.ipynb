# %%
! pip install pandas
! pip install numpy

# %%
import pandas as pd
import numpy as np

# Random seed for consistency
np.random.seed(42)

# Generating 500 rows of data
data = {
    'Customer_ID': range(101, 601),
    'Age': np.random.randint(18, 70, size=500),
    'Annual_Income_k$': np.random.randint(15, 150, size=500),
    'Spending_Score': np.random.randint(1, 101, size=500),
    'Membership_Years': np.random.randint(0, 10, size=500),
    'Gender': np.random.choice(['Male', 'Female'], size=500),
    'Preferred_Category': np.random.choice(['Electronics', 'Fashion', 'Home Decor', 'Groceries'], size=500)
}

df = pd.DataFrame(data)

df.to_csv('customer_data.csv', index=False)

# %%
df = pd.read_csv('customer_data.csv')

df.head()
# Out:
#    Customer_ID  Age  Annual_Income_k$  Spending_Score  Membership_Years  \
# 0          101   56                30              72                 8
# 1          102   69                83              92                 7
# 2          103   46                36              31                 8
# 3          104   32               107               9                 4
# 4          105   60                90              51                 1
#
#    Gender Preferred_Category
# 0  Female          Groceries
# 1  Female        Electronics
# 2  Female          Groceries
# 3  Female        Electronics
# 4  Female         Home Decor

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Age                   0
# Annual_Income_k$      0
# Spending_Score        0
# Membership_Years      0
# Gender                0
# Preferred_Category    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         500 non-null    int64
#  1   Age                 500 non-null    int64
#  2   Annual_Income_k$    500 non-null    int64
#  3   Spending_Score      500 non-null    int64
#  4   Membership_Years    500 non-null    int64
#  5   Gender              500 non-null    object
#  6   Preferred_Category  500 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 27.5+ KB

# %%
df.describe()
# Out:
#        Customer_ID         Age  Annual_Income_k$  Spending_Score  \
# count   500.000000  500.000000         500.00000      500.000000
# mean    350.500000   44.220000          81.28400       50.110000
# std     144.481833   15.036082          39.28075       29.012434
# min     101.000000   18.000000          15.00000        1.000000
# 25%     225.750000   32.000000          48.00000       25.000000
# 50%     350.500000   45.000000          82.00000       49.500000
# 75%     475.250000   57.000000         115.00000       74.000000
# max     600.000000   69.000000         149.00000      100.000000
#
#        Membership_Years
# count        500.000000
# mean           4.418000
# std            2.905884
# min            0.000000
# 25%            2.000000
# 50%            4.000000
# 75%            7.000000
# max            9.000000

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
sns.scatterplot(data=df, x='Age', y='Spending_Score', hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Spending_Score'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')

plt.show()

# %%
df['Preferred_Category'].value_counts().plot(kind='bar', color='orange')
plt.title('Top Shopping Categories')
plt.show()
